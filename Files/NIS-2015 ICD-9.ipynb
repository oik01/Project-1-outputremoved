# %%
import pandas as pd

# %%
file = '/Volumes/My Passport for Mac/NIS/2015 NIS/nis_2015_core_q1q3.sas7bdat'

# %%
NISchunk= pd.read_sas(file,format='sas7bdat', index=None, encoding='ISO-8859-1', chunksize= 100000)
chunk_list = []  # append each chunk df here

# %%
for chunk in NISchunk:  
    df_concat = pd.DataFrame(chunk)
    break
list(df_concat.columns)
# Out:
# ['AGE',
#  'AGE_NEONATE',
#  'AMONTH',
#  'AWEEKEND',
#  'DIED',
#  'DISCWT',
#  'DISPUNIFORM',
#  'DQTR',
#  'ELECTIVE',
#  'FEMALE',
#  'HCUP_ED',
#  'HOSP_DIVISION',
#  'HOSP_NIS',
#  'KEY_NIS',
#  'LOS',
#  'NIS_STRATUM',
#  'PAY1',
#  'PL_NCHS',
#  'RACE',
#  'TOTCHG',
#  'TRAN_IN',
#  'TRAN_OUT',
#  'YEAR',
#  'ZIPINC_QRTL',
#  'BODYSYSTEM1',
#  'BODYSYSTEM2',
#  'BODYSYSTEM3',
#  'BODYSYSTEM4',
#  'BODYSYSTEM5',
#  'BODYSYSTEM6',
#  'BODYSYSTEM7',
#  'BODYSYSTEM8',
#  'BODYSYSTEM9',
#  'BODYSYSTEM10',
#  'BODYSYSTEM11',
#  'BODYSYSTEM12',
#  'BODYSYSTEM13',
#  'BODYSYSTEM14',
#  'BODYSYSTEM15',
#  'BODYSYSTEM16',
#  'BODYSYSTEM17',
#  'BODYSYSTEM18',
#  'BODYSYSTEM19',
#  'BODYSYSTEM20',
#  'BODYSYSTEM21',
#  'BODYSYSTEM22',
#  'BODYSYSTEM23',
#  'BODYSYSTEM24',
#  'BODYSYSTEM25',
#  'BODYSYSTEM26',
#  'BODYSYSTEM27',
#  'BODYSYSTEM28',
#  'BODYSYSTEM29',
#  'BODYSYSTEM30',
#  'CHRON1',
#  'CHRON2',
#  'CHRON3',
#  'CHRON4',
#  'CHRON5',
#  'CHRON6',
#  'CHRON7',
#  'CHRON8',
#  'CHRON9',
#  'CHRON10',
#  'CHRON11',
#  'CHRON12',
#  'CHRON13',
#  'CHRON14',
#  'CHRON15',
#  'CHRON16',
#  'CHRON17',
#  'CHRON18',
#  'CHRON19',
#  'CHRON20',
#  'CHRON21',
#  'CHRON22',
#  'CHRON23',
#  'CHRON24',
#  'CHRON25',
#  'CHRON26',
#  'CHRON27',
#  'CHRON28',
#  'CHRON29',
#  'CHRON30',
#  'DRG',
#  'DRG_NoPOA',
#  'DRGVER',
#  'DX1',
#  'DX2',
#  'DX3',
#  'DX4',
#  'DX5',
#  'DX6',
#  'DX7',
#  'DX8',
#  'DX9',
#  'DX10',
#  'DX11',
#  'DX12',
#  'DX13',
#  'DX14',
#  'DX15',
#  'DX16',
#  'DX17',
#  'DX18',
#  'DX19',
#  'DX20',
#  'DX21',
#  'DX22',
#  'DX23',
#  'DX24',
#  'DX25',
#  'DX26',
#  'DX27',
#  'DX28',
#  'DX29',
#  'DX30',
#  'DXCCS1',
#  'DXCCS2',
#  'DXCCS3',
#  'DXCCS4',
#  'DXCCS5',
#  'DXCCS6',
#  'DXCCS7',
#  'DXCCS8',
#  'DXCCS9',
#  'DXCCS10',
#  'DXCCS11',
#  'DXCCS12',
#  'DXCCS13',
#  'DXCCS14',
#  'DXCCS15',
#  'DXCCS16',
#  'DXCCS17',
#  'DXCCS18',
#  'DXCCS19',
#  'DXCCS20',
#  'DXCCS21',
#  'DXCCS22',
#  'DXCCS23',
#  'DXCCS24',
#  'DXCCS25',
#  'DXCCS26',
#  'DXCCS27',
#  'DXCCS28',
#  'DXCCS29',
#  'DXCCS30',
#  'DXMCCS1',
#  'DXVER',
#  'E_CCS1',
#  'E_CCS2',
#  'E_CCS3',
#  'E_CCS4',
#  'E_MCCS1',
#  'ECODE1',
#  'ECODE2',
#  'ECODE3',
#  'ECODE4',
#  'HOSPBRTH',
#  'MDC',
#  'MDC_NoPOA',
#  'NCHRONIC',
#  'NDX',
#  'NECODE',
#  'NEOMAT',
#  'NPR',
#  'ORPROC',
#  'PCLASS1',
#  'PCLASS2',
#  'PCLASS3',
#  'PCLASS4',
#  'PCLASS5',
#  'PCLASS6',
#  'PCLASS7',
#  'PCLASS8',
#  'PCLASS9',
#  'PCLASS10',
#  'PCLASS11',
#  'PCLASS12',
#  'PCLASS13',
#  'PCLASS14',
#  'PCLASS15',
#  'PR1',
#  'PR2',
#  'PR3',
#  'PR4',
#  'PR5',
#  'PR6',
#  'PR7',
#  'PR8',
#  'PR9',
#  'PR10',
#  'PR11',
#  'PR12',
#  'PR13',
#  'PR14',
#  'PR15',
#  'PRCCS1',
#  'PRCCS2',
#  'PRCCS3',
#  'PRCCS4',
#  'PRCCS5',
#  'PRCCS6',
#  'PRCCS7',
#  'PRCCS8',
#  'PRCCS9',
#  'PRCCS10',
#  'PRCCS11',
#  'PRCCS12',
#  'PRCCS13',
#  'PRCCS14',
#  'PRCCS15',
#  'PRDAY1',
#  'PRDAY2',
#  'PRDAY3',
#  'PRDAY4',
#  'PRDAY5',
#  'PRDAY6',
#  'PRDAY7',
#  'PRDAY8',
#  'PRDAY9',
#  'PRDAY10',
#  'PRDAY11',
#  'PRDAY12',
#  'PRDAY13',
#  'PRDAY14',
#  'PRDAY15',
#  'PRMCCS1',
#  'PRVER',
#  'SERVICELINE']

# %%
# Each chunk is in df format
for chunk in NISchunk:  
    chunk_list.append(chunk[['AMONTH', 'DISCWT', 'DXCCS1', 'DXCCS2', 'DXCCS3', 'DXCCS4', 'DXCCS5', 'DXCCS6', 'DXCCS7', 'DXCCS8', 'DXCCS9', 'DXCCS10', 'DXCCS11', 'DXCCS12', 'DXCCS13', 'DXCCS14', 'DXCCS15', 'DXCCS16', 'DXCCS17', 'DXCCS18', 'DXCCS19', 'DXCCS20', 'DXCCS21', 'DXCCS22', 'DXCCS23', 'DXCCS24', 'DXCCS25','DXCCS26', 'DXCCS27', 'DXCCS28', 'DXCCS29', 'DXCCS30','HOSP_DIVISION', 'YEAR']])
    df_concat = pd.concat(chunk_list)
    #Create a column specifying if the discharge had a diagnosis of Influenza
Influenza= ['123']
df_concat['Influenza'] = df_concat['DXCCS1'].isin(Influenza)| df_concat['DXCCS2'].isin(Influenza)| df_concat['DXCCS3'].isin(Influenza)| df_concat['DXCCS4'].isin(Influenza)| df_concat['DXCCS5'].isin(Influenza)| df_concat['DXCCS6'].isin(Influenza)| df_concat['DXCCS7'].isin(Influenza)| df_concat['DXCCS8'].isin(Influenza)| df_concat['DXCCS9'].isin(Influenza)| df_concat['DXCCS10'].isin(Influenza)| df_concat['DXCCS11'].isin(Influenza)| df_concat['DXCCS12'].isin(Influenza)| df_concat['DXCCS13'].isin(Influenza)| df_concat['DXCCS14'].isin(Influenza)| df_concat['DXCCS15'].isin(Influenza)| df_concat['DXCCS16'].isin(Influenza)| df_concat['DXCCS17'].isin(Influenza)| df_concat['DXCCS18'].isin(Influenza)| df_concat['DXCCS19'].isin(Influenza)| df_concat['DXCCS20'].isin(Influenza)| df_concat['DXCCS21'].isin(Influenza)| df_concat['DXCCS22'].isin(Influenza)| df_concat['DXCCS23'].isin(Influenza)| df_concat['DXCCS24'].isin(Influenza)| df_concat['DXCCS25'].isin(Influenza)    
print(f'created a dataframe with influenza admissions')

    # Create a column specifying if the discharge had a diagnosis of myocardial infarction
MI = ['100']
df_concat['MI'] = df_concat['DXCCS1'].isin(MI)| df_concat['DXCCS2'].isin(MI)| df_concat['DXCCS3'].isin(MI)| df_concat['DXCCS4'].isin(MI)| df_concat['DXCCS5'].isin(MI)| df_concat['DXCCS6'].isin(MI)| df_concat['DXCCS7'].isin(MI)| df_concat['DXCCS8'].isin(MI)| df_concat['DXCCS9'].isin(MI)| df_concat['DXCCS10'].isin(MI)| df_concat['DXCCS11'].isin(MI)| df_concat['DXCCS12'].isin(MI)| df_concat['DXCCS13'].isin(MI)| df_concat['DXCCS14'].isin(MI)| df_concat['DXCCS15'].isin(MI)| df_concat['DXCCS16'].isin(MI)| df_concat['DXCCS17'].isin(MI)| df_concat['DXCCS18'].isin(MI)| df_concat['DXCCS19'].isin(MI)| df_concat['DXCCS20'].isin(MI)| df_concat['DXCCS21'].isin(MI)| df_concat['DXCCS22'].isin(MI)| df_concat['DXCCS23'].isin(MI)| df_concat['DXCCS24'].isin(MI)| df_concat['DXCCS25'].isin(MI)
print(f'created a dataframe with MI admissions' )
sum_df = pd.DataFrame(df_concat.loc[df_concat['Influenza']== True].groupby('AMONTH').sum())
    # Create a new data frame object grouped by region and month and only including influenza discharges
Influenza_Regional = pd.DataFrame(df_concat.loc[df_concat['Influenza']== True].groupby(['YEAR','HOSP_DIVISION','AMONTH']).sum())
Influenza_Regional = Influenza_Regional[['DISCWT']]
Influenza_Regional = Influenza_Regional.rename(columns = {'DISCWT': 'Influenza Incidence'})
print(f'created a dataframe with only regional Influenza admissions' )

    # Same process without region for a total incidence 
Influenza_Total = pd.DataFrame(df_concat.loc[df_concat['Influenza']== True].groupby(['YEAR','AMONTH']).sum())
Influenza_Total = Influenza_Total[['DISCWT']]
Influenza_Total = Influenza_Total.rename(columns = {'DISCWT': 'Influenza Incidence'})
print(f'created a dataframe with only total Influenza admissions incidence' )

    # MI Regional
MI_Regional = pd.DataFrame(df_concat.loc[df_concat['MI']== True].groupby(['YEAR','HOSP_DIVISION','AMONTH']).sum())
MI_Regional = MI_Regional[['DISCWT']]
MI_Regional = MI_Regional.rename(columns = {'DISCWT': 'MI Incidence'})
print(f'created a dataframe with only regional MI admissions incidence' )

    # MI Total
MI_Total = pd.DataFrame(df_concat.loc[df_concat['MI']== True].groupby(['YEAR','AMONTH']).sum())
MI_Total = MI_Total[['DISCWT']]
MI_Total = MI_Total.rename(columns = {'DISCWT': 'MI Incidence'})
print(f'created a dataframe with only total MI admissions incidence' )

Both_Regional = pd.merge(Influenza_Regional, MI_Regional, how = 'inner', on= ['YEAR','HOSP_DIVISION','AMONTH'])
Both_Total = pd.merge(Influenza_Total, MI_Total, how = 'inner', on= ['YEAR','AMONTH'])
# Out:
# created a dataframe with influenza admissions
# created a dataframe with MI admissions
# created a dataframe with only regional Influenza admissions
# created a dataframe with only total Influenza admissions incidence
# created a dataframe with only regional MI admissions incidence
# created a dataframe with only total MI admissions incidence

# %% [markdown]
# #

# %%
Both_Regional.to_csv("/Users/omarkreidieh/Documents/GitHub/Flu-Project/Output Files/2015_Regionalincidence.csv", index = True, header = True)

# %%
Both_Total.to_csv("/Users/omarkreidieh/Documents/GitHub/Flu-Project/Output Files/2015_Totalincidence.csv", index = True, header = True)

# %%
Both_Total
# Out:
#                Influenza Incidence  MI Incidence
# YEAR   AMONTH
# 2015.0 1.0            73275.013245  87254.969589
#        2.0            28534.996409  76699.975195
#        3.0            18730.023471  83279.990782
#        4.0             9915.007868  80269.978794
#        5.0             3500.000855  79584.988686
#        6.0             1770.009511  76304.976837
#        7.0             1005.000729  76859.992013
#        8.0              899.999425  75334.986515
#        9.0             1155.002870  61509.977781
#        10.0              30.000207     45.000337
#        11.0             130.000019    344.999756
#        12.0           17925.006695  15589.996016
