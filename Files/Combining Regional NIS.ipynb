# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt
import scipy.stats as stats
from tqdm import tqdm_notebook as tqdm

# %%
icd_9_regional = pd.read_csv('/Users/omarkreidieh/Documents/GitHub/Flu-Project/Output Files/ICD_9_Regionalincidence.csv')

# %%
icd_9_regional
# Out:
#        YEAR  HOSP_DIVISION  AMONTH  Influenza Incidence  MI Incidence
# 0    2014.0            1.0     1.0          2065.005037   4355.014709
# 1    2014.0            1.0     2.0          1700.004130   3795.008013
# 2    2014.0            1.0     3.0          1615.003040   4225.012756
# 3    2014.0            1.0     4.0          1775.006339   4195.012289
# 4    2014.0            1.0     5.0           560.003437   4225.014932
# 5    2014.0            1.0     6.0            80.000712   4100.005616
# 6    2014.0            1.0     7.0            30.000094   4155.013081
# 7    2014.0            1.0     8.0            35.000084   3980.012898
# 8    2014.0            1.0     9.0            55.000297   4035.008225
# 9    2014.0            1.0    10.0           150.000492   3880.006344
# 10   2014.0            1.0    11.0           205.000116   4150.011372
# 11   2014.0            1.0    12.0          1095.001104   4320.011143
# ...

# %%
icd_9_2015_total = pd.read_csv('/Users/omarkreidieh/Documents/GitHub/Flu-Project/Output Files/2015_Regionalincidence.csv')
icd_10_2015_total = pd.read_csv('/Users/omarkreidieh/Documents/GitHub/Flu-Project/Output Files/2015_Q4Totalincidence.csv')

# %%
combined_2015 = pd.merge(icd_9_2015_total, icd_10_2015_total, how = 'outer' )

# %%
combined_2015
# Out:
#        YEAR  HOSP_DIVISION  AMONTH  Influenza Incidence  MI Incidence
# 0    2015.0            1.0     1.0          3180.013584   2735.011467
# 1    2015.0            1.0     2.0          2135.005131   2525.005283
# 2    2015.0            1.0     3.0          1240.005788   2510.008181
# 3    2015.0            1.0     4.0           770.002700   2735.008378
# 4    2015.0            1.0     5.0           134.999917   2540.014625
# 5    2015.0            1.0     6.0            55.000191   2330.006300
# 6    2015.0            1.0     7.0            25.000027   2665.009362
# 7    2015.0            1.0     8.0             5.000010   2565.010813
# 8    2015.0            1.0     9.0            20.000170   1970.011690
# 9    2015.0            1.0    12.0           250.000659    540.002403
# 10   2015.0            2.0     1.0         13224.963606  12504.974555
# 11   2015.0            2.0     2.0          5599.993798  11309.987452
# ...

# %%
combined_2015 = combined_2015.groupby(['YEAR','HOSP_DIVISION','AMONTH']).sum()

# %%
pd.set_option('display.max_rows', 200)


combined_2015
# Out:
#                              Influenza Incidence  MI Incidence
# YEAR   HOSP_DIVISION AMONTH
# 2015.0 1.0           1.0             3180.013584   2735.011467
#                      2.0             2135.005131   2525.005283
#                      3.0             1240.005788   2510.008181
#                      4.0              770.002700   2735.008378
#                      5.0              134.999917   2540.014625
#                      6.0               55.000191   2330.006300
#                      7.0               25.000027   2665.009362
#                      8.0                5.000010   2565.010813
#                      9.0               20.000170   1970.011690
#                      12.0             250.000659    540.002403
#        2.0           1.0            13224.963606  12504.974555
#                      2.0             5599.993798  11309.987452
#                      3.0             2470.002284  11494.990818
# ...

# %%
df_2016 = pd.read_csv('/Users/omarkreidieh/Documents/GitHub/Flu-Project/Output Files/2016Regionalincidence.csv')
NIS_data = pd.concat([icd_9_regional, combined_2015, df_2016 ])
# Out:
# /Users/omarkreidieh/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
NIS_data.to_csv("/Users/omarkreidieh/Documents/GitHub/Flu-Project/Output Files/NIS_Regionalincidence.csv", index = False, header = True)
